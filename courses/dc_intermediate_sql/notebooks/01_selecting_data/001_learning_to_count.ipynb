# %%
import pandas as pd

df_reviews = pd.read_csv("../../datasets/csv/reviews.csv")

# %% [markdown]
# <h1>
# Count the number of records contained in the reviews table.
# </h1>

# %%
display(pd.DataFrame({"count_film_id": [df_reviews["film_id"].count()]}))
# Out:
#    count_film_id
# 0           4968
