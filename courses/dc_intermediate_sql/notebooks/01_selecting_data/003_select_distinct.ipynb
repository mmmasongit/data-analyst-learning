# %%
import pandas as pd

df_films = pd.read_csv("../../datasets/csv/films.csv")

# %% [markdown]
# <h1>
# Return the unique countries represented in the films table using DISTINCT.
# </h1>

# %%
display(df_films["country"].drop_duplicates())
# Out:
# 0            USA
# 3        Germany
# 61         Japan
# 63       Denmark
# 69            UK
#           ...
# 4515       Kenya
# 4690    Slovenia
# 4693    Pakistan
# 4756       Chile
# 4856      Panama
# Name: country, Length: 65, dtype: str

# %% [markdown]
# <h1>
# Return the number of unique countries represented in the films table, aliased as
# count_distinct_countries.
# </h1>

# %%
display(
    pd.DataFrame(
        {
            "count_distinct_countries": [
                df_films["country"].drop_duplicates().count()
            ]
        }
    )
)
# Out:
#    count_distinct_countries
# 0                        64
