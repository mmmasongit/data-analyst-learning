# %%
import pandas as pd

df_reviews = pd.read_csv("../../datasets/csv/reviews.csv")

# %% [markdown]
# <h1>
# Select the film_id and imdb_score from the reviews table and filter on scores
# higher than 7.0.
# </h1>

# %%
display(df_reviews)
# Out:
#       3934   588.0  432.0  7.0999999  203461  46000
# 0     3405   285.0  267.0        6.4  149998      0
# 1      478    65.0   29.0        3.2    8465    491
# 2       74    83.0   25.0        7.6    7071    930
# 3     1254  1437.0  224.0        8.0  241030  13000
# 4      740   111.0   64.0        6.4   64742      0
# ...    ...     ...    ...        ...     ...    ...
# 4962  4801     2.0    6.0        7.0      75    121
# 4963  4264   514.0  488.0        7.0  181472  58000
# 4964  4356    85.0  119.0        6.2   29738  12000
# 4965   430   118.0   38.0        5.9   29591      0
# 4966    29  1123.0  242.0        8.6  387508  23000
#
# [4967 rows x 6 columns]
