# %%
import pandas as pd

df_books = pd.read_csv("../../datasets/csv/books.csv")

# %% [markdown]
# <h1>
# Select the title from the books table to view all book titles.
# </h1>

# %%
display(df_books["title"])
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 345    Wild: From Lost to Found on the Pacific Crest ...
# 346    Winter of the World: Book Two of the Century T...
# 347    Women Food and God: An Unexpected Path to Almo...
# 348                                               Wonder
# 349         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# Name: title, Length: 350, dtype: str

# %% [markdown]
# <h1>
# Select title and author from the books table.
# </h1>

# %%
display(df_books[["title", "author"]])
# Out:
#                                                  title  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 345  Wild: From Lost to Found on the Pacific Crest ...
# 346  Winter of the World: Book Two of the Century T...
# 347  Women Food and God: An Unexpected Path to Almo...
# 348                                             Wonder
# 349       Wrecking Ball (Diary of a Wimpy Kid Book 14)
#
#                        author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 345            Cheryl Strayed
# 346               Ken Follett
# ...

# %% [markdown]
# <h1>
# Select all fields from the books table.
# </h1>

# %%
display(df_books)
# Out:
#       id                                              title  \
# 0      1                      10-Day Green Smoothie Cleanse
# 1      2                                  11/22/63: A Novel
# 2      3            12 Rules for Life: An Antidote to Chaos
# 3      4                             1984 (Signet Classics)
# 4      5  5,000 Awesome Facts (About Everything!) (Natio...
# ..   ...                                                ...
# 345  346  Wild: From Lost to Found on the Pacific Crest ...
# 346  347  Winter of the World: Book Two of the Century T...
# 347  348  Women Food and God: An Unexpected Path to Almo...
# 348  349                                             Wonder
# 349  350       Wrecking Ball (Diary of a Wimpy Kid Book 14)
#
#                        author  year        genre
# 0                    JJ Smith  2016  Non Fiction
# 1                Stephen King  2011      Fiction
# 2          Jordan B. Peterson  2018  Non Fiction
# ...
