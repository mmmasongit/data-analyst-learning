# %%
import pandas as pd

df_books = pd.read_csv("../../datasets/csv/books.csv")

# %% [markdown]
# <h1>
# Update the code to return the unique author and genre combinations in the
# books table.
# </h1>

# %%
display(df_books["author"].drop_duplicates().rename("unique_author"))
# Out:
# 0                               JJ Smith
# 1                           Stephen King
# 2                     Jordan B. Peterson
# 3                          George Orwell
# 4               National Geographic Kids
#                      ...
# 344    The Staff of The Late Show withÂ…
# 345                       Cheryl Strayed
# 346                          Ken Follett
# 347                          Geneen Roth
# 348                        R. J. Palacio
# Name: unique_author, Length: 247, dtype: str
