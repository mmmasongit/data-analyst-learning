# %%
import pandas as pd

df_books = pd.read_csv("../../datasets/csv/books.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2
#       3 df_books = pd.read_csv("../../datasets/csv/books.csv")
#
# File ~\Workspace\data-analyst-learning\.venv\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File ~\Workspace\data-analyst-learning\.venv\Lib\site-packages\pandas\core\config_init.py:31
#      19 import pandas._config.config as cf
# ...

# %% [markdown]
# <h1>
# Create a view called library_authors.
# </h1>

# %%
library_authors = (
    df_books[["author"]]
    .drop_duplicates()
    .rename(columns={"author": "unique_author"})
)

# %% [markdown]
# <h1>
# Check that the view was created by selecting all columns from library_authors.
# </h1>

# %%
display(library_authors)
# Out:
#                          unique_author
# 0                             JJ Smith
# 1                         Stephen King
# 2                   Jordan B. Peterson
# 3                        George Orwell
# 4             National Geographic Kids
# ..                                 ...
# 344  The Staff of The Late Show withÂ…
# 345                     Cheryl Strayed
# 346                        Ken Follett
# 347                        Geneen Roth
# 348                      R. J. Palacio
#
# [247 rows x 1 columns]
