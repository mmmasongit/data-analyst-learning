# %%
import pandas as pd

df_books = pd.read_csv("../../datasets/csv/books.csv")

# %% [markdown]
# <h1>
# Select the genre field from the books table; limit the number of results to 10.
# </h1>

# %%
display(df_books["genre"].head(10))
# Out:
# 0    Non Fiction
# 1        Fiction
# 2    Non Fiction
# 3        Fiction
# 4    Non Fiction
# 5        Fiction
# 6        Fiction
# 7        Fiction
# 8    Non Fiction
# 9        Fiction
# Name: genre, dtype: str
