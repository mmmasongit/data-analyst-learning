# %%
import pandas as pd

# %% [markdown]
# <p>Clean books.csv</p>

# %%
################################################################################
# Bronze Layer
################################################################################

# Step 1: Load data
df_books = pd.read_csv(
    "../../courses/dc_introduction_to_sql/datasets/csv/books.csv", header=None
)

################################################################################
# Silver Layer
################################################################################

# Step 1: Create header columns
df_books.columns = ["id", "title", "author", "year", "genre"]

display(df_books)
